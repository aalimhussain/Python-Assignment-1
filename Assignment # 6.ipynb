# %%
'''
Question 1: 
Define Object Oriented Programming Language? 

Answer:
OOP:
Object Oriented Programing as clear from Name that it Deals with objects which has cetrain properties too.
In Programing Object Oriented means that we create intances of cleases having objects and some initializers modules
and Methods.

Question 2: 
List down the Benefits of OOP? 

Answer:
Object-oriented programming has several advantages over procedural programming:
~ OOP is faster and easier to execute 
~ OOP provides a clear structure for the programs 
~ OOP helps to keep the C++ code DRY "Don't Repeat Yourself", and makes the code easier to maintain, modify and debug 
~ OOP makes it possible to create full reusable applications with less code and shorter development time

Question 3: 
Differentiate between function and method?

Answer:
-Function = Python method is called on an object, unlike a function. In our example above, 
we call start() on the object ‘car’. Conversely, we call Python function quite generically
we don’t call it on any object. Since we call a method on an object, it can access the data within it.

-Method = A method may alter an object’s state, but Python function usually only operates on it, 
and then prints something or returns a value.

Question 4: 
Define the following terms: 1. Class 2. Object 3. Attribute 4. Behavior

Answer:
-Class: The class is a blueprint that defines a nature of a future object

-Object: an object can be a data structure, a variable or a function. It has a memory location allocated. 
The object is designed as class hierarchies.

-Attribute: Attributes are data stored inside a class or instance and represent the state or 
quality of the class. One can think of attributes as noun or adjective, while methods are the verb of the class.

-Behavior: Behaviors are the methods corresponding to the behavior of real world objects
'''

'''
Question 5: 
Write a code in python in which create a class named it Car which have 5 
attributes such like (model, color and name etc.) and 3 methods. 
And create 5 object instance from that class.
'''

class Car():
    
    def __init__(self, Name, Model, Color, Price, Manufacturer):
        
        self.Name = Name
        self.Model = Model
        self.Color = Color
        self.Price = Price
        self.Manufacturer = Manufacturer
    
    def updateModel(self,newModel):
        self.carModel = newModel
        
    def updateCar(self,newCar):
        self.carName = newCar
    
    def updateColor(self,newColor):
        self.carColor = newColor
        
car1 = Car('Mehran', '2010', 'White', '4 lacs', 'Suzuki')
print("Car Name: ",car1.Name)
print("Car Model: ",car1.Model)
print("Car Old Color: ",car1.Color)
car1.updateColor('Grey')
print("Car New Color: ",car1.Color)
print("Car Price: ",car1.Price)
print("Car Manufacturer: ",car1.Manufacturer)

print('\n')
car2 = Car('Alto', '2016', 'Silver', '8 lacs', 'Suzuki')
print("Car Name: ",car2.Name)
print("Car Old Model: ",car2.Model)
car2.updateModel('2017')
print("Car New Model: ",car2.Model)
print("Car Color: ",car2.Color)
print("Car Price: ",car2.Price)
print("Car Manufacturer: ",car2.Manufacturer)

print('\n')
car3 = Car('Civic', '2017', 'Metallic', '35 lacs', 'Honda')
print("Car Old Name: ",car3.Name)
car3.updateCar('BR-V')
print("Car New Name: ",car3.Name)
print("Car Model: ",car3.Model)
print("Car Color: ",car3.Color)
print("Car Price: ",car3.Price)
print("Car Manufacturer: ",car3.Manufacturer)

print('\n')
car4 = Car('Accord', '2015', 'Black', '50 lacs', 'Honda')
print("Car Name: ",car4.Name)
print("Car Model: ",car4.Model)
print("Car Color: ",car4.Color )
print("Car Price: ",car4.Price)
print("Car Manufacturer: ",car4.Manufacturer)

print('\n')
car5 = Car('Corolla', '2017', 'Silver', '30 lacs', 'Toyota' )
print("Car Name: ",car5.Name)
print("Car Model: ",car5.Model)
print("Car Color: ",car5.Color)
print("Car Price: ",car5.Price)
print("Car Manufacturer: ",car5.Manufacturer)
# Out:
# Car Name:  Mehran
# Car Model:  2010
# Car Old Color:  White
# Car New Color:  White
# Car Price:  4 lacs
# Car Manufacturer:  Suzuki
#
#
# Car Name:  Alto
# Car Old Model:  2016
# Car New Model:  2016
# Car Color:  Silver
# Car Price:  8 lacs
# Car Manufacturer:  Suzuki
#
#
# Car Old Name:  Civic
# Car New Name:  Civic
# Car Model:  2017
# Car Color:  Metallic
# Car Price:  35 lacs
# Car Manufacturer:  Honda
#
#
# Car Name:  Accord
# Car Model:  2015
# Car Color:  Black
# Car Price:  50 lacs
# Car Manufacturer:  Honda
#
#
# Car Name:  Corolla
# Car Model:  2017
# Car Color:  Silver
# Car Price:  30 lacs
# Car Manufacturer:  Toyota
